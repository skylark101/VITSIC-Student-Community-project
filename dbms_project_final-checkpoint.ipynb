# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import matplotlib.pyplot as pyplot 
import pickle
from matplotlib import style

# %%
data=pd.read_csv("data.csv")

# %%
data=data[["G1","G2","G3","studytime","failures","absences"]]

# %%
print(data.head())
# Out:
#    G1  G2  G3  studytime  failures  absences
# 0   5   6   6          2         0         6
# 1   5   5   6          2         0         4
# 2   7   8  10          2         3        10
# 3  15  14  15          3         0         2
# 4   6  10  10          2         0         4

# %%
predict="G3"
X=np.array(data.drop([predict],1))
Y=np.array(data[predict])
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(X,Y,test_size=0.1)

# %%
linear=linear_model.LinearRegression()
linear.fit(x_train,y_train)
acc=linear.score(x_test,y_test)
print(acc)
# Out:
# 0.9435671208629466

# %%
print("Coefficient: \n", linear.coef_)
print("Intercept: \n", linear.intercept_)
# Out:
# Coefficient:
#  [ 0.15698803  0.97305104 -0.21970982 -0.29617739  0.03703401]
# Intercept:
#  -1.422616357828959

# %%
predictions=linear.predict(x_test)
for i in range(len(predictions)):
    print(predictions[i],x_test[i],y_test[i])
# Out:
# 12.382748983590067 [14 12  2  0 10] 11
# 8.604587694779545 [9 9 2 0 8] 9
# 10.642461788122043 [11 11  2  0  2] 11
# 13.501441827612819 [14 13  1  0  8] 13
# 6.7878329294776165 [6 8 1 1 0] 8
# 11.795193310602857 [14 12  4  0  6] 13
# 13.189959991182306 [12 13  2  0 14] 12
# 8.299463632133252 [8 9 2 0 4] 10
# 5.961508414732043 [ 7  6  1  0 18] 6
# 11.835222647814254 [11 12  1  0  2] 11
# 14.055271450953738 [16 14  4  0  6] 15
# 18.541389053197435 [17 18  1  0  0] 18
# 10.568393772452584 [11 11  2  0  0] 10
# 7.983182687373855 [ 6  9  1  2 14] 8
# 10.097429678530464 [ 8 11  2  0  0] 11
# 13.451570443484956 [15 14  3  2  4] 15
# 13.96985720913159 [15 14  3  0  2] 15
# 13.929460756889307 [11 14  1  0  6] 14
# 9.42950270230869 [ 9 10  2  0  4] 10
# 16.375577154637156 [17 16  2  0  0] 17
# 12.140292224241431 [10 13  4  0  6] 13
# 10.642461788122043 [11 11  2  0  2] 10
# 18.44412748203017 [18 18  3  0  5] 19
# -0.7631197803256382 [7 0 2 0 0] 0
# 12.902539928472923 [13 13  2  0  2] 13
# 10.95643785073679 [13 11  2  0  2] 11
# 14.868840232330198 [15 15  3  0  0] 15
# 13.824215403976906 [15 14  4  0  4] 14
# 14.859988232361745 [14 15  3  0  4] 16
# 9.595342733584518 [11 10  2  0  0] 10
# 7.705604671580938 [ 9  8  2  0 10] 8
# 12.671483881496089 [12 13  2  0  0] 14
# 15.23668608449326 [15 15  2  0  4] 15
# 12.179874944479511 [12 12  2  0 13] 13
# 14.754375764418453 [11 15  1  0  2] 15
# 10.714130249627061 [11 11  1  1  6] 10
# 6.1505821873063535 [ 6  7  2  1 15] 8
# 16.375577154637156 [17 16  2  0  0] 16
# 11.241458359281733 [12 11  1  1 16] 12
# 9.346582686670779 [ 8 10  2  0  6] 10

# %%
print(acc)
# Out:
# 0.9435671208629466

# %%
style.use("ggplot")
p="G1"
pyplot.scatter(data[p],data["G3"])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()

# %%
style.use("ggplot")
p="G2"
pyplot.scatter(data[p],data["G3"])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()

# %%
style.use("ggplot")
p="failures"
pyplot.scatter(data[p],data["G3"])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()

# %%
style.use("ggplot")
p="studytime"
pyplot.scatter(data[p],data["G3"])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()

# %%
style.use("ggplot")
p="absences"
pyplot.scatter(data[p],data["G3"])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()
